# %%
import pandas as pd
import zipfile

# %%
zipfile_name = "london-bike-sharing-dataset.zip" 
with zipfile.ZipFile(zipfile_name, 'r') as file:
    file.extractall()
    #extracting downloaded kaggle zip file

# %%
df = pd.read_csv("london_merged.csv")
#read csv as datafram

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (17414, 10)

# %%
df['weather_code'].value_counts()
#checking unique values for weather_code column
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df['season'].value_counts()
#checking unique values for season column
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
#renaming columns to have better access to them (creating dictionary)

new_cols_dict ={
    'timestamp':'time',
    'cnt':'count',
    't1':'real_temp_C',
    't2':'feel_temp_C',
    'hum':'humidity_percent',
    'wind_speed':'wind_speed_kph',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',
    'season':'season'
}

#renaming columns in dataframe
df.rename(new_cols_dict, axis=1, inplace=True)

# %%
df
# Out:
#                       time  count  real_temp_C  feel_temp_C  humidity_percent  \
# 0      2015-01-04 00:00:00    182          3.0          2.0              93.0
# 1      2015-01-04 01:00:00    138          3.0          2.5              93.0
# 2      2015-01-04 02:00:00    134          2.5          2.5              96.5
# 3      2015-01-04 03:00:00     72          2.0          2.0             100.0
# 4      2015-01-04 04:00:00     47          2.0          0.0              93.0
# ...                    ...    ...          ...          ...               ...
# 17409  2017-01-03 19:00:00   1042          5.0          1.0              81.0
# 17410  2017-01-03 20:00:00    541          5.0          1.0              81.0
# 17411  2017-01-03 21:00:00    337          5.5          1.5              78.5
# 17412  2017-01-03 22:00:00    224          5.5          1.5              76.0
# 17413  2017-01-03 23:00:00    139          5.0          1.0              76.0
#
# ...

# %%
#changing humidity value to percentage (0 - 1)
df.humidity_percent = df.humidity_percent / 100

# %%
df.humidity_percent
# Out:
# 0        0.930
# 1        0.930
# 2        0.965
# 3        1.000
# 4        0.930
#          ...
# 17409    0.810
# 17410    0.810
# 17411    0.785
# 17412    0.760
# 17413    0.760
# Name: humidity_percent, Length: 17414, dtype: float64

# %%
#changing seasons codes to seasons names / changing float to written values (creating dictionary)
season_dict = {
    '0.0':'spring',
    '1.0':'summer',
    '2.0':'autumn',
    '3.0':'winter'
}

#changing weather codes to weather names / changing float to written values (creating dictionary) 
#1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity 
#2 = scattered clouds /few clouds 
#3 = Broken clouds 
#4 = Cloudy 
#7 = Rain/ light Rain shower/ Light rain 
#10 = rain with thunderstorm 
#26 = snowfall 
#94 = Freezing Fog

weather_dict = {
    '1.0':'clear',
    '2.0':'scattered clouds',
    '3.0':'broken clouds',
    '4.0':'cloudy',
    '7.0':'Rain',
    '10.0':'Rain with thunderstorm',
    '26.0':'Snowfall',
    '94.0':'Freezing Fog',
}

#changing data type to string
df.season = df.season.astype('str')
#mapping values to dictionary ones
df.season = df.season.map(season_dict)

#changing data type to string
df.weather = df.weather.astype('str')
#mapping values to dictionary ones
df.weather = df.weather.map(weather_dict)

# %%
df
# Out:
#                       time  count  real_temp_C  feel_temp_C  humidity_percent  \
# 0      2015-01-04 00:00:00    182          3.0          2.0             0.930
# 1      2015-01-04 01:00:00    138          3.0          2.5             0.930
# 2      2015-01-04 02:00:00    134          2.5          2.5             0.965
# 3      2015-01-04 03:00:00     72          2.0          2.0             1.000
# 4      2015-01-04 04:00:00     47          2.0          0.0             0.930
# ...                    ...    ...          ...          ...               ...
# 17409  2017-01-03 19:00:00   1042          5.0          1.0             0.810
# 17410  2017-01-03 20:00:00    541          5.0          1.0             0.810
# 17411  2017-01-03 21:00:00    337          5.5          1.5             0.785
# 17412  2017-01-03 22:00:00    224          5.5          1.5             0.760
# 17413  2017-01-03 23:00:00    139          5.0          1.0             0.760
#
# ...

# %%
#Dataframe to excel file what can be used in Tableu visualisation
df.to_excel('london_bikes_processed.xlsx', sheet_name='Data')
